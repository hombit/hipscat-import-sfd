# %% [markdown]
# # Join SFD map with a point source catalog
#
# We need LSDB for that

# %%
from pathlib import Path

import dask
import lsdb
import numpy as np
import pandas as pd
from dask.distributed import Client
from dask_jobqueue import SLURMCluster
from hipscat.pixel_math.hipscat_id import HIPSCAT_ID_COLUMN, hipscat_id_to_healpix
from lsdb.core.crossmatch.abstract_crossmatch_algorithm import AbstractCrossmatchAlgorithm

# %% [markdown]
# Data paths
#
# Hardcoded path to PS1 DR2 object table (OTMO) and SFD map at PSC

# %%
# STARS_PATH = Path('/ocean/projects/phy210048p/shared/hipscat/catalogs/ps1/ps1_otmo')

# Use SDSS DR16 Quasar catalog for a while...
STARS_PATH = Path('/ocean/projects/phy210048p/shared/hipscat/catalogs/agns_dr16q_prop_May16')

# Fixed order 14 SFD map
SFD_PATH = Path('/ocean/projects/phy210048p/shared/hipscat/catalogs/sfd/sfd_order14_map')
# Multiorder SFD map, interpolation error is <1%
# SFD_PATH = Path('/ocean/projects/phy210048p/shared/hipscat/catalogs/sfd/sfd_multiorder_map')

# %% [markdown]
# ### We are using LSDB's cross-matching interface for joining

# %%
class JoinWithContinuousMap(AbstractCrossmatchAlgorithm):
    DISTANCE_COLUMN_NAME = '_DIST'
    
    def crossmatch(self) -> pd.DataFrame:
        # Check that both catalogs are sorted by HIPSCAT_ID_COLUMN
        assert np.all(np.diff(self.left.index) > 0)
        assert np.all(np.diff(self.right[HIPSCAT_ID_COLUMN]) > 0)
        
        # Initial implementation with the binary search, it is O(n_star * log(n_sfd))
        # For large star catalogs it is better to use the linear search, which is O(n_star + n_sfd)
        idx = np.searchsorted(self.right[HIPSCAT_ID_COLUMN], self.left.index, side='right') - 1
        
        # np.searchsorted output must be between 0 and N,
        # so we are checking -1 case only
        assert np.all(idx >= 0)
        
        self._rename_columns_with_suffix(self.left, self.suffixes[0])
        self._rename_columns_with_suffix(self.right, self.suffixes[1])
        
        left_join_part = self.left.reset_index()
        right_join_part = self.right.iloc[idx].reset_index(drop=True)
        
        out = pd.concat(
            [
                left_join_part,
                right_join_part,
            ],
            axis=1,
        )
        out[self.DISTANCE_COLUMN_NAME] = 0.0
        out.set_index(HIPSCAT_ID_COLUMN, inplace=True)
        
        return out

# %%
# Make a command for dashboard ssh-tunneling

import socket
from getpass import getuser
from urllib.parse import urlparse

local_addr = '127.0.0.1:8787'
remote_host = 'bridges2.psc.edu'


def print_client_info(client):
    display(client)
    
    with socket.socket(socket.AF_INET, socket.SOCK_DGRAM) as s:
        s.connect(('1.1.1.1', 53))
        ip = s.getsockname()[0]
    username = getuser()
    dashboard_port = urlparse(client.dashboard_link).port

    print(f'''
    Copy-paste and run in your terminal:

    ssh -N -L {local_addr}:{ip}:{dashboard_port} {username}@{remote_host}

    And open this URL in your browser to see the dashboard:
    http://{local_addr}/
    ''')

# %%
# %%time

# I have some connect issues runiing on PSC...
dask.config.set({
    'distributed.comm.timeouts.connect': '60s',
    'distributed.comm.timeouts.tcp': '60s',
})

# with SLURMCluster(
#     # Number of Dask workers per node
#     processes=4,
#     # Regular memory node type on PSC bridges2
#     queue="RM",
#     # dask_jobqueue requires cores and memory to be specified
#     # We set them to match RM specs
#     cores=128,
#     memory="256GB",
#     walltime="12:00:00",
# ) as cluster:
#     # Run multiple jobs
#     # cluster.scale(jobs=10)
#     # Allow to run more jobs
#     cluster.adapt(maximum_jobs=10)

#     with Client(cluster) as client:
with Client(n_workers=8) as client:
        print_client_info(client)

        stars = lsdb.read_hipscat(STARS_PATH)
        sfd = lsdb.read_hipscat(SFD_PATH)
        matched = stars.crossmatch(sfd, algorithm=JoinWithContinuousMap)
        mean_sfd = matched._ddf[f'ebv_{sfd.name}'].mean().compute()
mean_sfd
# Out:
# <Client: 'tcp://127.0.0.1:42759' processes=8 threads=128, memory=247.07 GiB>
#     Copy-paste and run in your terminal:
#
#     ssh -N -L 127.0.0.1:8787:10.8.9.182:8787 malanche@bridges2.psc.edu
#
#     And open this URL in your browser to see the dashboard:
#     http://127.0.0.1:8787/
# 2023-12-06 11:14:57,695 - distributed.utils_perf - WARNING - full garbage collections took 60% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:08,487 - distributed.utils_perf - WARNING - full garbage collections took 60% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:16,432 - distributed.utils_perf - WARNING - full garbage collections took 57% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:19,312 - distributed.utils_perf - WARNING - full garbage collections took 57% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:23,312 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:28,146 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:38,093 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:43,217 - distributed.utils_perf - WARNING - full garbage collections took 63% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:43,234 - distributed.utils_perf - WARNING - full garbage collections took 63% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:43,587 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:48,046 - distributed.utils_perf - WARNING - full garbage collections took 59% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:57,546 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:15:58,124 - distributed.utils_perf - WARNING - full garbage collections took 65% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:03,322 - distributed.utils_perf - WARNING - full garbage collections took 63% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:05,855 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:07,148 - distributed.utils_perf - WARNING - full garbage collections took 62% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:16,220 - distributed.utils_perf - WARNING - full garbage collections took 66% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:22,043 - distributed.utils_perf - WARNING - full garbage collections took 60% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:22,306 - distributed.utils_perf - WARNING - full garbage collections took 62% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:30,475 - distributed.utils_perf - WARNING - full garbage collections took 61% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:32,015 - distributed.utils_perf - WARNING - full garbage collections took 62% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:36,538 - distributed.utils_perf - WARNING - full garbage collections took 67% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:43,992 - distributed.utils_perf - WARNING - full garbage collections took 64% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:53,298 - distributed.utils_perf - WARNING - full garbage collections took 60% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:53,734 - distributed.utils_perf - WARNING - full garbage collections took 62% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:58,902 - distributed.utils_perf - WARNING - full garbage collections took 60% CPU time recently (threshold: 10%)
# 2023-12-06 11:16:59,506 - distributed.utils_perf - WARNING - full garbage collections took 67% CPU time recently (threshold: 10%)
# 2023-12-06 11:17:07,141 - distributed.utils_perf - WARNING - full garbage collections took 64% CPU time recently (threshold: 10%)
# 2023-12-06 11:17:11,346 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/worker.py", line 1255, in heartbeat
#     response = await retry_operation(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1396, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1155, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:40622 remote=tcp://127.0.0.1:42759>: Stream is closed
# 2023-12-06 11:17:13,950 - distributed.nanny - WARNING - Worker process still alive after 3.1999989318847657 seconds, killing
# 2023-12-06 11:17:13,951 - distributed.nanny - WARNING - Worker process still alive after 3.19999984741211 seconds, killing
# 2023-12-06 11:17:13,952 - distributed.nanny - WARNING - Worker process still alive after 3.19999984741211 seconds, killing
# 2023-12-06 11:17:13,952 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-06 11:17:13,954 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-06 11:17:13,954 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-06 11:17:13,955 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-06 11:17:13,956 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# CPU times: user 6min 6s, sys: 34.4 s, total: 6min 40s
# Wall time: 6min 33s
# 0.0359235139702884

# %% [markdown]
# Alternative approach: use dustmaps package

# %%
# %%time
import dask
import pandas as pd
from astropy.coordinates import SkyCoord
from dustmaps.sfd import SFDQuery

# Get original SFD FITS file location, INPUT_DIR
from paths import *


def worker(df, query):
    coord = SkyCoord(
        ra=df[stars.hc_structure.catalog_info.ra_column],
        dec=df[stars.hc_structure.catalog_info.dec_column],
        unit='deg',
    )
    ebv = query(coord)
    return pd.DataFrame(dict(ebv=ebv), index=df.index)


with Client(n_workers=24) as client:
    print_client_info(client)
    
    query = dask.delayed(SFDQuery, pure=True, traverse=False)(INPUT_DIR)
    
    stars = lsdb.read_hipscat(STARS_PATH)
    values = stars._ddf.map_partitions(worker, query, meta={'ebv': np.float32})
    mean_values = values.mean().compute()
    
mean_values
# Out:
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# <Client: 'tcp://127.0.0.1:39345' processes=24 threads=144, memory=247.07 GiB>
#     Copy-paste and run in your terminal:
#
#     ssh -N -L 127.0.0.1:8787:10.8.10.22:8787 malanche@bridges2.psc.edu
#
#     And open this URL in your browser to see the dashboard:
#     http://127.0.0.1:8787/
#
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# 2023-12-04 15:44:58,877 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/worker.py", line 1255, in heartbeat
#     response = await retry_operation(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1396, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1155, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43064 remote=tcp://127.0.0.1:39345>: Stream is closed
# 2023-12-04 15:44:58,877 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/worker.py", line 1255, in heartbeat
#     response = await retry_operation(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1396, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1155, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43066 remote=tcp://127.0.0.1:39345>: Stream is closed
# 2023-12-04 15:44:58,946 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/worker.py", line 1255, in heartbeat
#     response = await retry_operation(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 455, in retry_operation
#     return await retry(
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/utils_comm.py", line 434, in retry
#     return await coro()
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1396, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/core.py", line 1155, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/jet/home/malanche/.virtualenvs/sfd/lib/python3.9/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:43048 remote=tcp://127.0.0.1:39345>: Stream is closed
# Configuration file not found:
#
#     /jet/home/malanche/.dustmapsrc
#
# To create a new configuration file in the default location, run the following python code:
#
#     from dustmaps.config import config
#     config.reset()
#
# Note that this will delete your configuration! For example, if you have specified a data directory, then dustmaps will forget about its location.
# 2023-12-04 15:45:02,070 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,071 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,072 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,073 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,074 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,075 - distributed.nanny - WARNING - Worker process still alive after 3.1999992370605472 seconds, killing
# 2023-12-04 15:45:02,075 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,076 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,077 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,078 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,079 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,079 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,082 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,082 - distributed.nanny - WARNING - Worker process still alive after 3.199999389648438 seconds, killing
# 2023-12-04 15:45:02,083 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2023-12-04 15:45:02,085 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,085 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2023-12-04 15:45:02,086 - distributed.nanny - WARNING - Worker process still alive after 3.19999984741211 seconds, killing
# 2023-12-04 15:45:02,087 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# 2023-12-04 15:45:02,087 - distributed.nanny - WARNING - Worker process still alive after 3.199999694824219 seconds, killing
# 2023-12-04 15:45:02,109 - distributed.nanny - WARNING - Worker process still alive after 3.1999995422363288 seconds, killing
# CPU times: user 4min 13s, sys: 42.4 s, total: 4min 55s
# Wall time: 4min 35s
# ebv    0.035924
# dtype: float64

# %% [markdown]
# ### Validation
#
# First, we check that both hipscat indexes and SFD pixel index-order pair are all consistent

# %%
np.testing.assert_array_equal(
    hipscat_id_to_healpix(result[f'_hipscat_index_{SFD_NAME}'], result[f'pixel_Norder_{SFD_NAME}']),
    result[f'pixel_Npix_{SFD_NAME}'],
)
np.testing.assert_array_equal(
    hipscat_id_to_healpix(result.index, result[f'pixel_Norder_{SFD_NAME}']),
    result[f'pixel_Npix_{SFD_NAME}'],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 np.testing.assert_array_equal(
# ----> 2     hipscat_id_to_healpix(result[f'_hipscat_index_{SFD_NAME}'], result[f'pixel_Norder_{SFD_NAME}']),
#       3     result[f'pixel_Npix_{SFD_NAME}'],
#       4 )
#       5 np.testing.assert_array_equal(
#       6     hipscat_id_to_healpix(result.index, result[f'pixel_Norder_{SFD_NAME}']),
#       7     result[f'pixel_Npix_{SFD_NAME}'],
#       8 )
#
# NameError: name 'SFD_NAME' is not defined

# %% [markdown]
# Check that SFD map values are close enough to the ones from `dustmap` module.
# The difference must be below 16% for fixed order and 1% for multiorder.

# %%
# Validate
from astropy.coordinates import SkyCoord
from dustmaps.sfd import SFDQuery

sfd_query = SFDQuery(INPUT_DIR)
coord = SkyCoord(ra=result['ra_small_sky_order1'], dec=result['dec_small_sky_order1'], unit='deg')
dustmaps_sfd_values = sfd_query(coord)

diff = (
    np.abs(result[f'ebv_{SFD_NAME}'] - dustmaps_sfd_values)
    / np.where(result[f'ebv_{SFD_NAME}'] > dustmaps_sfd_values, result[f'ebv_{SFD_NAME}'], dustmaps_sfd_values)
)
i = np.argsort(diff)[::-1]
display(result.assign(diff=diff, ebv_dustmap=dustmaps_sfd_values).iloc[i[:10]])
diff.max()

# %%
area17 = 4 ** (17 - sfd._ddf['pixel_Norder'].astype(np.uint64))
area17.sum().compute(), 12 * 4 ** 17

# %%
import pyarrow.parquet as pq

for norder in range(8, 18):
    count = (sfd._ddf['pixel_Norder'] == norder).sum().compute()
    count_real = pq.read_metadata(PARQUET_DIR / f'pixel_Norder={norder:02d}.parquet').num_rows
    print(norder, count - count_real)

# %%
import dask.array as da

index = sfd._ddf['_hipscat_index'].to_dask_array(lengths=True)
display(da.sum(da.diff(index) <= 0).compute())
index.argmin().compute()

# %%
from hipscat.pixel_math.hipscat_id import healpix_to_hipscat_id

index = sfd._ddf['_hipscat_index'].to_dask_array(lengths=True)
diff_index = da.diff(index)
diff_index_from_norder = sfd._ddf['pixel_Norder'].to_dask_array(lengths=True).astype(np.uint64).map_blocks(lambda order: healpix_to_hipscat_id(order, 1))[:-1]

da.sum((diff_index != diff_index_from_norder).astype(np.uint64)).compute()
